# %% [markdown]
# # MY BEST HOLIDAYS

# %%
[section title](#presentation)
[section title](#personal-name)
[section title](#personal-photo)
[section title](#holiday-preference)
[section title](#destination-photo)
[section title](#top-3-points)
[section title](#video-link)

# %% [markdown]
# # presentation

# %% [markdown]
# **Hi, my name is Dámaris and travelling to Bali was my best vacation. I'm going to share some photos and a link video below.**

# %% [markdown]
# # personal-name

# %%
value = input("Person's name:\n")

# %% [markdown]
# # personal-photo

# %% [markdown]
# _Here's a photo of mine with landscape in Bali._

# %% [markdown]
# ![IMG-20180117-WA0181.jpg](attachment:IMG-20180117-WA0181.jpg)

# %% [markdown]
# # holiday-preference

# %% [markdown]
# Now let's see some reasons for me to go to Bali:

# %%
value = input("Holiday preference:\n")

# %% [markdown]
# # destination-photo

# %% [markdown]
# _Here's another photo of Bali._

# %% [markdown]
# ![20180227_161455.jpg](attachment:20180227_161455.jpg)

# %% [markdown]
# # top-3-points

# %% [markdown]
# The top 3 things I loved to do there:
#    - Eat and discover new food recipes
#    - Enjoying sunsets, sunrises, landscapes, etcetera.
#    - Learning about culture.

# %% [markdown]
# # video-link

# %% [markdown]
# _Here I link a video of the destination:_

# %% [markdown]
# https://www.youtube.com/watch?v=2b9txcAt4e0

# %% [markdown]
# (note: I am so frustrated because the input function previously worked but now there's no way to activate the cells when I click on "run". And the same with the [section title], it does not run. I check on google also for some additional information, I made a question on slack and on chat but nobody answered me. I would like to know what am I doing incorrectly. Thank you)
